# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
m=2.5
c=1.8

# %%
X=np.arange(-20,20,1)
y=m*X+c+np.random.normal(0,2.5,len(X))
plt.scatter(X,y)

# %%
slope=10
intercept=8

# %%
def draw(slope,intercept):
  plt.scatter(X,y)
  Y_hat=slope*X+intercept
  plt.plot(X,Y_hat,'r')

draw(slope,intercept)

# %%
Y_hat=slope*X+intercept
cost= sum((y-Y_hat)**2)/len(X)
cost
# Out:
# np.float64(7465.750633590124)

# %%
delta_m=sum((Y_hat-y)*X)/len(X)
delta_c=sum((Y_hat-y))/len(X)
delta_m,delta_c
# Out:
# (np.float64(995.1147644967583), np.float64(2.707045581194637))

# %%
Lr=0.01

# %%
for i in range(100):
  delta_m=sum((Y_hat-y)*X)/len(X)
  delta_c=sum((Y_hat-y))/len(X)
  slope=slope-Lr*delta_m
  intercept=intercept-Lr*delta_c
  Y_hat=slope*X+intercept

print(slope,intercept)
draw(slope,intercept)
# Out:
# 2.5307735165984235 3.9281726593561572

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
model= linear_model.LinearRegression()
model.fit(X.reshape(-1,1),y)
# Out:
# LinearRegression()

# %%
model.coef_,model.intercept_
# Out:
# (array([2.52181398]), np.float64(1.5538614083462448))

# %%
plt.scatter(X,y)
plt.plot(X,Y_hat,'r')
Y_sk=model.coef_*X+model.intercept_
