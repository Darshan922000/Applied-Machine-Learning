# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def my_pol(x):
    return x**2 - 6*x + 8

def der(x):
    return 2*x - 6

def draw(x):
    #plt.plot(x,y)
    plt.scatter(x, my_pol(x), c='r')
    plt.show()

# %%
x = np.arange(-20, 20, 0.2)
y = x**2 - 6*x + 8

# %%
cur_x = -15
plt.plot(x,y)
draw(cur_x)

# %%
x_new = cur_x - 0.01 * der(cur_x)
print(x_new)
plt.plot(x,y)
draw(x_new)
# Out:
# -14.64

# %%
plt.plot(x, y)
lr = 0.01
for i in range(100):
    cur_x = x_new
    x_new = cur_x - lr * der(cur_x)
draw(cur_x)
print(cur_x)
# Out:
# 0.6128479938944419
